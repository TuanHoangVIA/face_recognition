# %%
import face_recognition
import numpy as np
import os
import cv2

# Create arrays of known face encodings and their names
known_face_encodings = []
known_face_names = []

root_directory = "D:/Workspace/AI/deeplearning/Img_Member_Via/"
# Duyệt qua từng thư mục con
for directory_name in os.listdir(root_directory):
    # Tạo đường dẫn đến thư mục con
    sub_directory = os.path.join(root_directory, directory_name)
    
    # Kiểm tra xem nó có phải là một thư mục
    if os.path.isdir(sub_directory):
        # Duyệt qua từng tệp ảnh trong thư mục con
        for image_name in os.listdir(sub_directory):
            # Kiểm tra định dạng tệp ảnh (ví dụ: jpg, png)
            if image_name.lower().endswith((".jpg", ".jpeg", ".png")):
                
                # Đường dẫn đầy đủ đến tệp ảnh
                image_path = os.path.join(sub_directory, image_name)
                print(image_path)
                image = cv2.imread(image_path)
                small_image = cv2.resize(image, (0, 0), fx=0.25, fy=0.25)  # Thay đổi tỷ lệ fx và fy để điều chỉnh kích thước
                face_locations = face_recognition.face_locations(small_image)
                arr = face_recognition.face_encodings(small_image, face_locations)
                if (arr != []):
                    img_encoding = arr[0]
                    known_face_encodings.append(img_encoding)
                    known_face_names.append(directory_name)
                else:
                    print("Không tìm thấy khuôn mặt trong ảnh:", image_name)
            else:
                print("Tệp không phải ảnh:", image_name)

print('Learned encoding for', len(known_face_encodings), 'images.')
# Out:
# D:/Workspace/AI/deeplearning/Img_Member_Via/DoanNgocAnh\DoanNgocAnh (1).JPG
# D:/Workspace/AI/deeplearning/Img_Member_Via/DoanNgocAnh\DoanNgocAnh (2).JPG
# D:/Workspace/AI/deeplearning/Img_Member_Via/DoanNgocAnh\DoanNgocAnh (3).JPG
# Không tìm thấy khuôn mặt trong ảnh: DoanNgocAnh (3).JPG
# D:/Workspace/AI/deeplearning/Img_Member_Via/DoanNgocAnh\DoanNgocAnh (4).JPG
# Không tìm thấy khuôn mặt trong ảnh: DoanNgocAnh (4).JPG
# D:/Workspace/AI/deeplearning/Img_Member_Via/DoanNgocAnh\DoanNgocAnh (5).JPG
# Không tìm thấy khuôn mặt trong ảnh: DoanNgocAnh (5).JPG
# D:/Workspace/AI/deeplearning/Img_Member_Via/DoanNgocAnh\DoanNgocAnh (6).JPG
# D:/Workspace/AI/deeplearning/Img_Member_Via/DoHoangPhuongDuy\DoHoangPhuongDuy (1).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/DoHoangPhuongDuy\DoHoangPhuongDuy (10).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/DoHoangPhuongDuy\DoHoangPhuongDuy (11).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/DoHoangPhuongDuy\DoHoangPhuongDuy (2).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/DoHoangPhuongDuy\DoHoangPhuongDuy (3).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/DoHoangPhuongDuy\DoHoangPhuongDuy (4).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/DoHoangPhuongDuy\DoHoangPhuongDuy (5).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/DoHoangPhuongDuy\DoHoangPhuongDuy (6).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/DoHoangPhuongDuy\DoHoangPhuongDuy (7).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/DoHoangPhuongDuy\DoHoangPhuongDuy (8).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/DoHoangPhuongDuy\DoHoangPhuongDuy (9).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/DoThiThuyNhuong\DoThiThuyNhuong (1).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/DoThiThuyNhuong\DoThiThuyNhuong (2).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/DoThiThuyNhuong\DoThiThuyNhuong (3).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/DoThiThuyNhuong\DoThiThuyNhuong (4).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/DoThiThuyNhuong\DoThiThuyNhuong (5).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/DoThiThuyNhuong\DoThiThuyNhuong (6).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/DoThiThuyNhuong\DoThiThuyNhuong (7).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/DoThiThuyNhuong\DoThiThuyNhuong (8).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/DoVanTruong\DoVanTruong (1).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/DoVanTruong\DoVanTruong (2).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/DoVanTruong\DoVanTruong (3).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/DoVanTruong\DoVanTruong (4).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/DoVanTruong\DoVanTruong (5).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/DoVanTruong\DoVanTruong (6).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/DoVanTruong\DoVanTruong (7).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/DoVanTruong\DoVanTruong (8).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/DuongDinhCuong\DuongDinhCuong (1).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/DuongDinhCuong\DuongDinhCuong (10).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/DuongDinhCuong\DuongDinhCuong (2).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/DuongDinhCuong\DuongDinhCuong (3).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/DuongDinhCuong\DuongDinhCuong (4).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/DuongDinhCuong\DuongDinhCuong (5).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/DuongDinhCuong\DuongDinhCuong (6).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/
jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/NguyenTranDiemQuynh\NguyenTranDiemQuynh (5).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/NguyenTranDiemQuynh\NguyenTranDiemQuynh (6).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/NguyenTranDiemQuynh\NguyenTranDiemQuynh (7).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/NguyenTranDiemQuynh\NguyenTranDiemQuynh (8).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/NguyenTranDiemQuynh\NguyenTranDiemQuynh (9).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/NguyenVanLoi\NguyenVanLoi (1).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/NguyenVanLoi\NguyenVanLoi (10).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/NguyenVanLoi\NguyenVanLoi (2).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/NguyenVanLoi\NguyenVanLoi (3).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/NguyenVanLoi\NguyenVanLoi (4).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/NguyenVanLoi\NguyenVanLoi (5).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/NguyenVanLoi\NguyenVanLoi (6).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/NguyenVanLoi\NguyenVanLoi (7).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/NguyenVanLoi\NguyenVanLoi (8).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/NguyenVanLoi\NguyenVanLoi (9).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/TangNgocCuong\TangNgocCuong (1).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/TangNgocCuong\TangNgocCuong (10).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/TangNgocCuong\TangNgocCuong (2).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/TangNgocCuong\TangNgocCuong (3).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/TangNgocCuong\TangNgocCuong (4).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/TangNgocCuong\TangNgocCuong (5).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/TangNgocCuong\TangNgocCuong (6).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/TangNgocCuong\TangNgocCuong (7).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/TangNgocCuong\TangNgocCuong (8).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/TangNgocCuong\TangNgocCuong (9).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/Tuan\7a1e4f9580e654b80df77.jpg
# Không tìm thấy khuôn mặt trong ảnh: 7a1e4f9580e654b80df77.jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/Tuan\b6b88b28445b9005c94a5.jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/Tuan\be1d7e8db1fe65a03cef6.jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/Tuan\ef91d51a1a69ce3797788.jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/Vu\57996e09a17a75242c6b3.jpg
# Không tìm thấy khuôn mặt trong ảnh: 57996e09a17a75242c6b3.jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/Vu\9b68a5f86a8bbed5e79a4.jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/Vu\c927f8b737c4e39abad51.jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/Vu\f8d9c3490c3ad864812b2.jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/VuongThiQuyen\VuongThiQuyen (1).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/VuongThiQuyen\VuongThiQuyen (10).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/VuongThiQuyen\VuongThiQuyen (2).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/VuongThiQuyen\VuongThiQuyen (3).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/VuongThiQuyen\VuongThiQuyen (4).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/VuongThiQuyen\VuongThiQuyen (5).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/VuongThiQuyen\VuongThiQuyen (6).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/VuongThiQuyen\VuongThiQuyen (7).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/VuongThiQuyen\VuongThiQuyen (8).jpg
# D:/Workspace/AI/deeplearning/Img_Member_Via/VuongThiQuyen\VuongThiQuyen (9).jpg
# Learned encoding for 148 images.

# %%
video_capture = cv2.VideoCapture(0)

# Initialize some variables
face_locations = []
face_encodings = []
face_names = []
process_this_frame = True

while True:
    # Grab a single frame of video
    ret, frame = video_capture.read()

    # Resize frame of video to 1/4 size for faster face recognition processing
    small_frame = cv2.resize(frame, (0, 0), fx=0.25, fy=0.25)

    rgb_small_frame = cv2.cvtColor(small_frame, cv2.COLOR_BGR2RGB)

    # Only process every other frame of video to save time
    if process_this_frame:
        # Find all the faces and face encodings in the current frame of video
        face_locations = face_recognition.face_locations(rgb_small_frame)
        face_encodings = face_recognition.face_encodings(rgb_small_frame, face_locations)

        face_names = []
        for face_encoding in face_encodings:
            # See if the face is a match for the known face(s)
            matches = face_recognition.compare_faces(known_face_encodings, face_encoding)
            name = "Unknown"

            # # If a match was found in known_face_encodings, just use the first one.
            # if True in matches:
            #     first_match_index = matches.index(True)
            #     name = known_face_names[first_match_index]

            # Or instead, use the known face with the smallest distance to the new face
            face_distances = face_recognition.face_distance(known_face_encodings, face_encoding)
            best_match_index = np.argmin(face_distances)
            if matches[best_match_index]:
                name = known_face_names[best_match_index]

            face_names.append(name)

    process_this_frame = not process_this_frame

    # Display the results
    for (top, right, bottom, left), name in zip(face_locations, face_names):
        # Scale back up face locations since the frame we detected in was scaled to 1/4 size
        top *= 4
        right *= 4
        bottom *= 4
        left *= 4

        # Draw a box around the face
        cv2.rectangle(frame, (left, top), (right, bottom), (0, 0, 255), 2)

        # Draw a label with a name below the face
        cv2.rectangle(frame, (left, bottom - 35), (right, bottom), (0, 0, 255), cv2.FILLED)
        font = cv2.FONT_HERSHEY_DUPLEX
        cv2.putText(frame, name, (left + 6, bottom - 6), font, 1.0, (255, 255, 255), 1)

    # Display the resulting image
    cv2.imshow('Video', frame)

    # Hit 'q' on the keyboard to quit!
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release handle to the webcam
video_capture.release()
cv2.destroyAllWindows()
